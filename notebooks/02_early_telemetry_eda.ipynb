# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

import pandas as pd
import matplotlib.pyplot as plt

from src.data.fastf1_client import FastF1Client

year = 2023
gp = "Monaco"
session = "R"

client = FastF1Client(year, gp, session)
client.load_session()

# 1. Get all laps
laps = client.get_laps()
print("All Laps DataFrame head:")
display(laps.head())

# 2. Get laps for a specific driver
laps_ver = client.get_laps("VER")
print("VER Laps DataFrame head:")
display(laps_ver.head())

# 3. Get telemetry for a specific driver
telemetry_ver = client.get_telemetry("VER")
print("VER Telemetry DataFrame head:")
display(telemetry_ver.head())

# 4. Get list of drivers
drivers = client.get_drivers()
print("Drivers in session:")
print(drivers)

# 5. Get weather data (if available)
if hasattr(client.event, "weather_data"):
    weather = client.event.weather_data
    print("Weather DataFrame head:")
    display(weather.head())
# Out:
# core           INFO 	Loading data for Monaco Grand Prix - Race [v3.6.0]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# Loading 2023 Monaco R
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '14', '31', '44', '63', '16', '10', '55', '4', '81', '77', '21', '24', '23', '22', '11', '27', '2', '20', '18']
# ...
